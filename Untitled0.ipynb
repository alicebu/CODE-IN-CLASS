# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebu/CODE-IN-CLASS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Save the file path
p1 = '/content/Base_IPC.xlsx'

# Read file
d_excel = pd.read_excel(p1)

# Check
d_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Ciudades                                   24 non-null     object
#  1   Ali Y Beb No Alcohólicas                   24 non-null     float64
#  2   Beb Alcohólicas Y Tabaco                   24 non-null     float64
#  3   Prendas De Vestir Y Calzado                24 non-null     float64
#  4   Servicios                                  24 non-null     float64
#  5    Para La Conservación Ordinaria Del Hogar  24 non-null     float64
#  6   Salud                                      24 non-null     float64
#  7   Transporte                                 24 non-null     float64
#  8   Información Y Comunicación                 24 non-null     float64
#  9   Recreación Y Cultura                       24 non-null     float64
# ...

# %%
# Save the file path
p2 = '/content/Base_IPC.csv'
# Read file
d_csv = pd.read_csv(p2, sep = ';')

# Check
d_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Ciudades                                   24 non-null     object
#  1   Ali Y Beb No Alcohólicas                   24 non-null     object
#  2   Beb Alcohólicas Y Tabaco                   24 non-null     object
#  3   Prendas De Vestir Y Calzado                24 non-null     object
#  4   Servicios                                  24 non-null     object
#  5    Para La Conservación Ordinaria Del Hogar  24 non-null     object
#  6   Salud                                      24 non-null     object
#  7   Transporte                                 24 non-null     object
#  8   Información Y Comunicación                 24 non-null     object
#  9   Recreación Y Cultura                       24 non-null     object
# ...

# %%
# Save the file path
p3 = '/content/Base_IPC.txt'
# Read file
BX = pd.read_csv(p3, sep = '\t', encoding= 'unicode_escape')

# Check
BX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Ciudades                                   24 non-null     object
#  1   Ali Y Beb No Alcohólicas                   24 non-null     object
#  2   Beb Alcohólicas Y Tabaco                   24 non-null     object
#  3   Prendas De Vestir Y Calzado                24 non-null     object
#  4   Servicios                                  24 non-null     object
#  5    Para La Conservación Ordinaria Del Hogar  24 non-null     object
#  6   Salud                                      24 non-null     object
#  7   Transporte                                 24 non-null     object
#  8   Información Y Comunicación                 24 non-null     object
#  9   Recreación Y Cultura                       24 non-null     object
# ...

# %% [markdown]
# #2.Explore

# %% [markdown]
# ###2.1. Preview

# %%
# Preview 0

d_excel.shape
# Out:
# (24, 14)

# %%
# Preview 1

BX.head(2)
# Out:
#     Ciudades Ali Y Beb No Alcohólicas Beb Alcohólicas Y Tabaco  \
# 0  Total IPC                    -0,25                     0,54
# 1   Medellín                    -0,01                     0,31
#
#   Prendas De Vestir Y Calzado Servicios  \
# 0                        0,07      0,21
# 1                       -0,01      0,11
#
#    Para La Conservación Ordinaria Del Hogar Salud Transporte  \
# 0                                      0,09  0,17       0,48
# 1                                      0,19  0,14       0,38
#
#   Información Y Comunicación Recreación Y Cultura Educación  \
# 0                       0,96                 1,41      0,00
# 1                       1,02                 2,07      0,00
#
#   Restaurantes Y Hoteles Bienes Y Servicios Diversos Total
# 0                   0,50                        0,16  0,26
# 1                   1,07                        0,32  0,35

# %%
# Preview 2

d_excel.tail
# Out:
# <bound method NDFrame.tail of                Ciudades  Ali Y Beb No Alcohólicas  Beb Alcohólicas Y Tabaco  \
# 0             Total IPC                     -0.25                      0.54
# 1              Medellín                     -0.01                      0.31
# 2          Barranquilla                      0.29                      0.68
# 3          Bogotá, D.C.                     -0.68                      0.95
# 4   Cartagena De Indias                     -0.22                      0.43
# 5                 Tunja                     -0.71                      0.32
# 6             Manizales                      0.04                      0.15
# 7             Florencia                     -0.07                      0.66
# 8               Popayán                      0.03                      0.66
# 9            Valledupar                      0.21                      0.02
# 10             Montería                      0.06                      0.86
# ...

# %%
# Save the file path
p1 = '/content/IPC.xlsx'

# Read file
IPC = pd.read_excel(p1)

# Check
IPC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 15 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Meses                                      24 non-null     datetime64[ns]
#  1   Ciudades                                   24 non-null     object
#  2   Ali Y Beb No Alcohólicas                   24 non-null     float64
#  3   Beb Alcohólicas Y Tabaco                   24 non-null     float64
#  4   Prendas De Vestir Y Calzado                24 non-null     float64
#  5   Servicios                                  24 non-null     float64
#  6    Para La Conservación Ordinaria Del Hogar  24 non-null     float64
#  7   Salud                                      24 non-null     float64
#  8   Transporte                                 24 non-null     float64
#  9   Información Y Comunicación                 24 non-null     float64
# ...

# %%
# Preview 2

IPC.tail
# Out:
# <bound method NDFrame.tail of         Meses             Ciudades  Ali Y Beb No Alcohólicas  \
# 0  2021-02-02            Total IPC                     -0.25
# 1  2021-03-06             Medellín                     -0.01
# 2  2021-04-07         Barranquilla                      0.29
# 3  2021-05-09         Bogotá, D.C.                     -0.68
# 4  2021-06-10  Cartagena De Indias                     -0.22
# 5  2021-07-12                Tunja                     -0.71
# 6  2021-08-13            Manizales                      0.04
# 7  2021-09-14            Florencia                     -0.07
# 8  2021-10-16              Popayán                      0.03
# 9  2021-11-17           Valledupar                      0.21
# 10 2021-12-19             Montería                      0.06
# 11 2022-01-20                Neiva                     -0.15
# 12 2022-02-21             Riohacha                      1.28
# 13 2022-03-25          Santa Marta                      0.07
# ...

# %% [markdown]
# #3.Add more info

# %%
# Extract the year

IPC[''] = IPC['Date'].Base_IPC.Year

IPC.head()

# %%
# Extract the year
ed['Year'] = ed['Date'].ed.year

# Extract the Quarter
ed['Quarter'] = ed['DATE'].ed.quarter

# Extract the Month
ed['Month'] = ed['DATE'].ed.month

# Extract the Week
ed['Week'] = ed['DATE'].ed.week

# Extract the Weekday
ed['Weekday'] = ed['DATE'].ed.weekday

# Extract the Day
df['Day'] = df['Date'].dt.day


ed.head()

# %% [markdown]
# #2.3. Reindex

# %%
IPC = IPC.set_index('Meses')
IPC.head()
# Out:
#                        Ciudades  Ali Y Beb No Alcohólicas  \
# Meses
# 2021-02-02            Total IPC                     -0.25
# 2021-03-06             Medellín                     -0.01
# 2021-04-07         Barranquilla                      0.29
# 2021-05-09         Bogotá, D.C.                     -0.68
# 2021-06-10  Cartagena De Indias                     -0.22
#
#             Beb Alcohólicas Y Tabaco  Prendas De Vestir Y Calzado  Servicios  \
# Meses
# 2021-02-02                      0.54                         0.07       0.21
# 2021-03-06                      0.31                        -0.01       0.11
# 2021-04-07                      0.68                         0.17       0.42
# 2021-05-09                      0.95                         0.05       0.13
# 2021-06-10                      0.43                         0.09       0.15
#
#              Para La Conservación Ordinaria Del Hogar  Salud  Transporte  \
# Meses
# ...

# %%
import plotly.express as px

# %%
##2.4 Simple graph

# %%
fig = px.line(IPC,title = 'IPC')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-a6da4ce46fda> in <module>
# ----> 1 fig = px.line(IPC,title = 'IPC')
#       2 fig.show()
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     260     a polyline mark in 2D space.
#     261     """
# --> 262     return make_figure(args=locals(), constructor=go.Scatter)
#     263
# ...
